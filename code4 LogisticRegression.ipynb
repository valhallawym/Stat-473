# %% [markdown]
# # Logistic Regression

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split 

from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, make_scorer
from sklearn.metrics import roc_curve

# %%
bank_df = pd.read_csv('UniversalBank.csv')
bank_df['Education'] =  bank_df['Education'].astype('category')

# %%
X = bank_df.drop(['ID','ZIP Code','Personal Loan'],axis=1)
X.head()
# Out:
#    Age  Experience  Income  Family  CCAvg  Mortgage Education  \
# 0   25           1      49       4    1.6         0         1
# 1   45          19      34       3    1.5         0         1
# 2   39          15      11       1    1.0         0         1
# 3   35           9     100       1    2.7         0         2
# 4   35           8      45       4    1.0         0         2
#
#    Securities Account  CD Account  Online  CreditCard
# 0                   1           0       0           0
# 1                   1           0       0           0
# 2                   0           0       0           0
# 3                   0           0       0           0
# 4                   0           0       0           1

# %%
y=bank_df['Personal Loan']
y = y.astype('category')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1,stratify=y)

# %%
logistic = LogisticRegression()
logistic.fit(X, y)
# Out:
# C:\Users\valha\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logistic.predict(X_test)

# %%
confmat = pd.DataFrame(confusion_matrix(y_test, y_pred),
                      index=['True[0]','True[1]'],
                      columns=['Predict[0]', 'Predict[1]'])
confmat
# Out:
#          Predict[0]  Predict[1]
# True[0]        1337          19
# True[1]          59          85

# %%
y_pred_p = logistic.predict_proba(X_test)
y_pred_p
# Out:
# array([[5.90341523e-01, 4.09658477e-01],
#        [9.83584828e-01, 1.64151716e-02],
#        [9.97828123e-01, 2.17187655e-03],
#        ...,
#        [9.14366899e-01, 8.56331007e-02],
#        [9.99458954e-01, 5.41045845e-04],
#        [8.81855415e-01, 1.18144585e-01]])

# %%
X1 = X
X1 = sm.add_constant(X1)
logis = sm.Logit(y,X1)

# %%
logistic_coef = logis.fit()
logistic_coef.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.128435
#          Iterations 9
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                            Results: Logit
# ====================================================================
# Model:                Logit             Method:            MLE
# Dependent Variable:   Personal Loan     Pseudo R-squared:  0.594
# Date:                 2024-02-27 00:06  AIC:               1308.3528
# No. Observations:     5000              BIC:               1386.5591
# Df Model:             11                Log-Likelihood:    -642.18
# Df Residuals:         4988              LL-Null:           -1581.0
# Converged:            1.0000            LLR p-value:       0.0000
# No. Iterations:       9.0000            Scale:             1.0000
# --------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# --------------------------------------------------------------------
# const              -12.1927   1.6452 -7.4112 0.0000 -15.4171 -8.9682
# Age                 -0.0536   0.0613 -0.8744 0.3819  -0.1738  0.0666
# Experience           0.0638   0.0609  1.0464 0.2954  -0.0557  0.1832
# Income               0.0546   0.0026 20.8313 0.0000   0.0494  0.0597
# Family               0.6958   0.0743  9.3637 0.0000   0.5501  0.8414
# CCAvg                0.1240   0.0396  3.1269 0.0018   0.0463  0.2017
# Mortgage             0.0005   0.0006  0.8562 0.3919  -0.0006  0.0016
# Education            1.7362   0.1151 15.0882 0.0000   1.5106  1.9617
# Securities Account  -0.9368   0.2859 -3.2771 0.0010  -1.4971 -0.3765
# CD Account           3.8225   0.3239 11.8001 0.0000   3.1876  4.4574
# Online              -0.6752   0.1571 -4.2983 0.0000  -0.9830 -0.3673
# CreditCard          -1.1197   0.2050 -5.4624 0.0000  -1.5215 -0.7180
# ====================================================================
#
# """
